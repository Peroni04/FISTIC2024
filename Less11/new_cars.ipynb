# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression

import warnings
warnings.filterwarnings('ignore')

# %%
path = 'cars_cleaned.csv'
df=pd.read_csv(path,sep=",")
df['brand'] = df['name'].str.split().str[0]
df=df.drop(columns="name")

# %%
df
# Out:
#      year   Price  kms_driven fuel_type      brand
# 0    2007   800.0       45000    Petrol    Hyundai
# 1    2006  4250.0          40    Diesel   Mahindra
# 2    2014  3250.0       28000    Petrol    Hyundai
# 3    2014  5750.0       36000    Diesel       Ford
# 4    2012  1750.0       41000    Diesel       Ford
# ..    ...     ...         ...       ...        ...
# 812  2009  3000.0      132000    Petrol     Toyota
# 813  2018  2600.0       27000    Diesel       Tata
# 814  2013  3900.0       40000    Diesel   Mahindra
# 815  2014  1800.0       50000    Petrol      Honda
# 816  2014  1600.0       50000    Petrol  Chevrolet
#
# [817 rows x 5 columns]

# %%
TARGET = 'Price'
X = df.drop([TARGET], axis=1)
y = df[TARGET]

# %%
columns_to_ohe = ["fuel_type","brand"]

OHE = ColumnTransformer([('ohe', OneHotEncoder(handle_unknown='ignore',drop='first'),columns_to_ohe )],
                        remainder='passthrough',  # Keep other columns unchanged
                        )

scaler = StandardScaler()

classifier = LinearRegression()
#classifier = LogistiRegression()

# %%
model_pipe = Pipeline([
                        ('Preprocessing features', OHE),
                        ('Scaling and standardize data', scaler),
                        ('Classifier', classifier)
                        ])

# %%
from sklearn.model_selection import cross_val_predict, StratifiedKFold
from sklearn.metrics import classification_report,confusion_matrix

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=667)
y_pred = cross_val_predict(model_pipe, X, y, cv=cv)

report = classification_report(y, y_pred)
print(report)

conf_matrix = confusion_matrix(y, y_pred)

plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels, cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 5
#       2 from sklearn.metrics import classification_report,confusion_matrix
#       4 cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=667)
# ----> 5 y_pred = cross_val_predict(model_pipe, X, y, cv=cv)
#       7 report = classification_report(y, y_pred)
#       8 print(report)
#
# File c:\Users\0304f\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Users\0304f\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:1256, in cross_val_predict(estimator, X, y, groups, cv, n_jobs, verbose, fit_params, params, pre_dispatch, method)
#    1253     routed_params.estimator = Bunch(fit=params)
#    1255 cv = check_cv(cv, y, classifier=is_classifier(estimator))
# -> 1256 splits = list(cv.split(X, y, **routed_params.splitter.split))
#    1258 test_indices = np.concatenate([test for _, test in splits])
#    1259 if not _check_is_permutation(test_indices, _num_samples(X)):
#
# File c:\Users\0304f\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_split.py:416, in _BaseKFold.split(self, X, y, groups)
#     408 if self.n_splits > n_samples:
#     409     raise ValueError(
#     410         (
#     411             "Cannot have number of splits n_splits={0} greater"
#     412             " than the number of samples: n_samples={1}."
#     413         ).format(self.n_splits, n_samples)
#     414     )
# --> 416 for train, test in super().split(X, y, groups):
#     417     yield train, test
#
# File c:\Users\0304f\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_split.py:147, in BaseCrossValidator.split(self, X, y, groups)
#     145 X, y, groups = indexable(X, y, groups)
#     146 indices = np.arange(_num_samples(X))
# --> 147 for test_index in self._iter_test_masks(X, y, groups):
#     148     train_index = indices[np.logical_not(test_index)]
#     149     test_index = indices[test_index]
#
# File c:\Users\0304f\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_split.py:809, in StratifiedKFold._iter_test_masks(self, X, y, groups)
#     808 def _iter_test_masks(self, X, y=None, groups=None):
# --> 809     test_folds = self._make_test_folds(X, y)
#     810     for i in range(self.n_splits):
#     811         yield test_folds == i
#
# File c:\Users\0304f\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_split.py:752, in StratifiedKFold._make_test_folds(self, X, y)
#     750 allowed_target_types = ("binary", "multiclass")
#     751 if type_of_target_y not in allowed_target_types:
# --> 752     raise ValueError(
#     753         "Supported target types are: {}. Got {!r} instead.".format(
#     754             allowed_target_types, type_of_target_y
#     755         )
#     756     )
#     758 y = column_or_1d(y)
#     760 _, y_idx, y_inv = np.unique(y, return_index=True, return_inverse=True)
#
# ValueError: Supported target types are: ('binary', 'multiclass'). Got 'continuous' instead.
